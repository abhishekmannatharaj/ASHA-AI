# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishekmannatharaj/ASHA-AI/blob/main/pyoops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
item1 = 'Phone'
item1_price = 100
item1_quantity = 5
item1_price_total = item1_price * item1_quantity

print(type(item1))
print(type(item1_price))
print(type(item1_quantity))
print(type(item1_price_total))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
